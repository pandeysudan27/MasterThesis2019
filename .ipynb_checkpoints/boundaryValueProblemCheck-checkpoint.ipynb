# %%
using DifferentialEquations
using BoundaryValueDiffEq
using OrdinaryDiffEq
using Plots
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\pande\.julia\compiled\v1.0\DifferentialEquations\UQdwS.ji for DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1190

# %%
const g = 9.81
L = 1.0
timespan = (0.0,pi/2)
function simplependulum!(dT,T,p,x)
    dT[1] = T[2]
    dT[2] = -(g/L)*sin(T[1])
end

function bc1!(residual, T, p, x)
    residual[1] = T[end÷2][1] + pi/2 # the solution at the middle of the time span should be -pi/2
    residual[2] = T[end][2] - pi/2 # the solution at the end of the time span should be pi/2
end
bvp1 = BVProblem(simplependulum!, bc1!, [pi/2,pi/2], timespan)
sol1 = solve(bvp1, Shooting(Vern7()))
plot(sol1)

# %%
a,b=sol1
plot(a,b[1])
# Out:
# MethodError: Cannot `convert` an object of type Array{Float64,1} to an object of type Float64
# Closest candidates are:
#   convert(::Type{T<:Number}, !Matched::T<:Number) where T<:Number at number.jl:6
#   convert(::Type{T<:Number}, !Matched::Number) where T<:Number at number.jl:7
#   convert(::Type{T<:Number}, !Matched::Base.TwicePrecision) where T<:Number at twiceprecision.jl:250
#   ...
#
# Stacktrace:
#  [1] setindex!(::Array{Float64,2}, ::Array{Float64,1}, ::Int64) at .\array.jl:769
#  [2] _replace!(::getfield(Base, Symbol("#new#230")){Tuple{Pair{Missing,Float64}}}, ::Array{Float64,2}, ::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},BVProblem{Array{Float64,1},Tuple{Float64,Float64},true,Nothing,ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},typeof(bc1!),DiffEqBase.StandardBVProblem,Nothing},Vern7,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Vern7Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern7ConstantCache{Float64,Float64}}}}, ::Int64) at .\set.jl:555
#  [3] #replace#232 at .\set.jl:382 [inlined]
#  [4] replace at .\set.jl:448 [inlined]
#  [5] handlemissings at C:\Users\pande\.julia\packages\Plots\UQI78\src\series.jl:40 [inlined]
#  [6] convertToAnyVector at C:\Users\pande\.julia\packages\Plots\UQI78\src\series.jl:31 [inlined]
#  [7] macro expansion at C:\Users\pande\.julia\packages\Plots\UQI78\src\series.jl:138 [inlined]
#  [8] apply_recipe(::Dict{Symbol,Any}, ::Type{Plots.SliceIt}, ::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},BVProblem{Array{Float64,1},Tuple{Float64,Float64},true,Nothing,ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},typeof(bc1!),DiffEqBase.StandardBVProblem,Nothing},Vern7,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Vern7Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern7ConstantCache{Float64,Float64}}}}, ::Array{Float64,1}, ::Nothing) at C:\Users\pande\.julia\packages\RecipesBase\Uz5AO\src\RecipesBase.jl:275
#  [9] _process_userrecipes(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},BVProblem{Array{Float64,1},Tuple{Float64,Float64},true,Nothing,ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},typeof(bc1!),DiffEqBase.StandardBVProblem,Nothing},Vern7,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Vern7Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern7ConstantCache{Float64,Float64}}}},Array{Float64,1}}) at C:\Users\pande\.julia\packages\Plots\UQI78\src\pipeline.jl:83
#  [10] _plot!(::Plots.Plot{Plots.GRBackend}, ::Dict{Symbol,Any}, ::Tuple{ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},BVProblem{Array{Float64,1},Tuple{Float64,Float64},true,Nothing,ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},typeof(bc1!),DiffEqBase.StandardBVProblem,Nothing},Vern7,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Vern7Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern7ConstantCache{Float64,Float64}}}},Array{Float64,1}}) at C:\Users\pande\.julia\packages\Plots\UQI78\src\plot.jl:178
#  [11] #plot#136(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::Function, ::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},BVProblem{Array{Float64,1},Tuple{Float64,Float64},true,Nothing,ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},typeof(bc1!),DiffEqBase.StandardBVProblem,Nothing},Vern7,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Vern7Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern7ConstantCache{Float64,Float64}}}}, ::Vararg{Any,N} where N) at C:\Users\pande\.julia\packages\Plots\UQI78\src\plot.jl:57
#  [12] plot(::ODESolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},BVProblem{Array{Float64,1},Tuple{Float64,Float64},true,Nothing,ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},typeof(bc1!),DiffEqBase.StandardBVProblem,Nothing},Vern7,OrdinaryDiffEq.InterpolationData{ODEFunction{true,typeof(simplependulum!),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.Vern7Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Vern7ConstantCache{Float64,Float64}}}}, ::Array{Float64,1}) at C:\Users\pande\.julia\packages\Plots\UQI78\src\plot.jl:51
#  [13] top-level scope at In[7]:2

# %%
plot(1,1,lc=:blue,la=0.5,label="Twc")
plot!(1,1,lc=:blue,label="Twc")
plot!(sol1.t,[sol1.u[i][1] for i in 1:length(sol1.t)],lc=:blue,label="")
plot!(sol1.t,[sol1.u[i][2] for i in 1:length(sol1.t)],lc=:blue, label="")

# %%
using DifferentialEquations
using BoundaryValueDiffEq
using OrdinaryDiffEq
using Plots
#parameters for BVProblem
#p=[UP,mda,mdw,aa,ba,aw,bw,chpa,chpw]
plot(1,1,lc=:red,la=1,lw=1.5,label=L"$T_a^\mathrm{c}$")
plot!(1,1,lc=:blue,la=1,lw=1.5,label=L"$T_w^\mathrm{h}$")
p=[0.88,49.2,53.9,3.42,1.21e-04,3.86,4.01e-04,1.15,4.2]
#length span of heat exchanger
xspan=(0.0,50.0)
function heatExchanger!(dT,T,p,time)
    #Note that heatexchanger model of bernt lie and that of
    #project description x-direction is opposite so we neglect - sign in the formula here

    dT[1]=p[1]/(p[2]*(p[8]))*(T[2]-T[1])
    dT[2]=p[1]/(p[3]*(p[9]))*(T[2]-T[1])
    #dT[3]=p[1]*(T[2]-T[1])
end

##initialGuess=[Tah,Twh]
initialGuess=[42.27,3.8]
function bc!(residual,T,p,time)
    residual[1]=T[1][1]-42.27#Tah
    residual[2]=T[1][2]-3.8#Twc
    #residual[3]=T[1][3]+1125.64#Twc
end

bvp=BVProblem(heatExchanger!,bc!,initialGuess,xspan,p)
sol=solve(bvp, Shooting(Vern7()))
plot!(sol)

# %%
x=[60,120,180,60*4,60*5,60*6]
y=rand(6)
plot(x/60,y)

# %%
plot(x,y)
